# %%
players = ["Ali", "Reza", "Hassan", "Amir", "Mohsen"]

def show_players():
    print("==Team Players==")
    for player in players:
        print(player)
    print("Number of players:",len(players))
    
    
    print("**"*10)
def check_players():
    for player in players:
        if player == "Ali":
            print(player,"-> Captain")
        else:
            print(player,"-> Player")


print("*"*20)
def remove_last_player():
    last = players.pop()
    print("Removed player:",last)


    print("*"*20)

show_players()

check_players()

remove_last_player()

show_players()

# %%
# Out:
# === Students Scores ===
# 📚 Score: 95
# 📚 Score: 72
# 📚 Score: 88
# 📚 Score: 60
# 📚 Score: 45
# 📚 Score: 100
# Number of scores: 6
# ____________________
# 95 -> Passed ✅
# 72 -> Failed ❌
# 88 -> Passed ✅
# 60 -> Failed ❌
# 45 -> Failed ❌
# 100 -> Passed ✅
# ____________________
# Removed score: 100
# === Students Scores ===
# 📚 Score: 95
# 📚 Score: 72
# 📚 Score: 88
# 📚 Score: 60
# 📚 Score: 45
# Number of scores: 5
# ____________________
